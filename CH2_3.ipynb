# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
sns.set_context('notebook')

# Load data from CSV file
df = pd.read_csv('weight-height.csv', skiprows=0, delimiter=',')
row_count = len(df)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.tail()
# Out:
#       Gender     Height      Weight
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103

# %%
print(df.describe().T)
# Out:
#           count        mean        std        min         25%         50%  \
# Height  10000.0   66.367560   3.847528  54.263133   63.505620   66.318070
# Weight  10000.0  161.440357  32.108439  64.700127  135.818051  161.212928
#
#                75%         max
# Height   69.174262   78.998742
# Weight  187.169525  269.989699

# %%
X = 2.54*df["Height"]
y  = 0.453592*df["Weight"]

def Calculate(item, label):
    mean_length = np.mean(item)
    median_length = np.median(item)
    std_dev_length = np.std(item)
    variance_length = np.var(item)

    print(f"\nPopulation of {row_count} {label}:")
    print("Mean: {:.2f}".format(mean_length))
    print("Median: {:.2f}".format(median_length))
    print("Std Dev: {:.2f}".format(std_dev_length))
    print("Var: {:.2f}".format(variance_length))

Calculate(X, label='Height')
Calculate(y, label='Weight')
# Out:
# Population of 10000 Height:
# Mean: 168.57
# Median: 168.45
# Std Dev: 9.77
# Var: 95.50
#
# Population of 10000 Weight:
# Mean: 73.23
# Median: 73.12
# Std Dev: 14.56
# Var: 212.09

# %%
ax = sns.pairplot(df[['Height','Weight','Gender']],hue='Gender',height=3.5, aspect=1.5, palette=("dark"), plot_kws = {"s":20})
plt.subplots_adjust(hspace=0.2)
ax = ax.map_diag(plt.hist)
